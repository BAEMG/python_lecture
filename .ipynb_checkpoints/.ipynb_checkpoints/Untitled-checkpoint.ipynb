# %%
a= True
b= False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af8fe5c0e545> in <module>
# ----> 1 a= true
#       2 b= false
#
# NameError: name 'true' is not defined

# %%
print(type(a))
# Out:
# <function print>

# %%
1==1
# Out:
#   File "<ipython-input-3-b2c65ab9a71d>", line 1
#     1 1=1
#       ^
# SyntaxError: invalid syntax

# %%
2<1
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
if "ddd" :
      print(3)
else:
        print(5)
# Out:
# 3

# %%
bool(None)
# Out:
# False

# %%
pi = 3.141592
type(pi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-c0b8bb4f12f9> in <module>
#       1 pi = 3.141592
# ----> 2 type(pi)
#
# TypeError: 'float' object is not callable

# %%
greet = "hello"
def print_greet():
    print(greet)
